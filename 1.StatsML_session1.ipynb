# %% [markdown]
# # Section 1: Descriptive Statistics - Mean, Mode, Median, standard Deviation, Variance and Inter Quartile Range
#
# *** DO play around with the code. Try different fnction from the library

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# x=np.random.randint(1,30,10) # code to generate 10 random numbers between 1 to 30

# %%
l1=[1,3,3,5,7]

# %%
sum(l1)
# Out:
# 19

# %%
len(l1)
# Out:
# 5

# %%
mean_l1=sum(l1)/len(l1)
mean_l1
# Out:
# 3.8

# %%
l1.mean() # can't do, we need a package
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b12fd6917960> in <module>
# ----> 1 l1.mean()
#
# AttributeError: 'list' object has no attribute 'mean'

# %%
import statistics as st # More details at https://docs.python.org/3/library/statistics.html
st.mean(l1)
# Out:
# 3.8

# %%
st.median(l1)
# Out:
# 3

# %%
st.mode(l1)
# Out:
# 3

# %%
st.stdev(l1)
# Out:
# 2.280350850198276

# %%
dir(st) # to check all the functions in the model
# Out:
# ['Counter',
#  'Decimal',
#  'Fraction',
#  'NormalDist',
#  'StatisticsError',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_coerce',
#  '_convert',
#  '_exact_ratio',
#  '_fail_neg',
#  '_find_lteq',
#  '_find_rteq',
#  '_isfinite',
#  '_normal_dist_inv_cdf',
#  '_ss',
#  '_sum',
#  'bisect_left',
#  'bisect_right',
#  'erf',
#  'exp',
#  'fabs',
#  'fmean',
#  'fsum',
#  'geometric_mean',
#  'groupby',
#  'harmonic_mean',
#  'hypot',
#  'itemgetter',
#  'log',
#  'math',
#  'mean',
#  'median',
#  'median_grouped',
#  'median_high',
#  'median_low',
#  'mode',
#  'multimode',
#  'numbers',
#  'pstdev',
#  'pvariance',
#  'quantiles',
#  'random',
#  'sqrt',
#  'stdev',
#  'tau',
#  'variance']

# %%
range_l1=max(l1)-min(l1)
range_l1
# Out:
# 6

# %%
box_dt=[70,65,90,100,104,107,95]

# %%
st.median(box_dt)
# Out:
# 95

# %%
# import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.boxplot(y=box_dt)
plt.show()

# %%
sns.boxplot(x=box_dt)
plt.show()
